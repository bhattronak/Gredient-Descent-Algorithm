# %%
import numpy as np
import matplotlib.pyplot as plt

def gredient_descent(x,y):
    m_curr=b_curr=0
    iterations=10000
    
    n=len(x)
    learning_rate=0.001

    for i in range(iterations):
        y_predicted=m_curr*x+b_curr
        cost_fun=(1/n)*sum((y- y_predicted* y_predicted))
        dcm=-(2/n)*sum(x*(y- y_predicted))
        dcb=-(2/n)*sum(y- y_predicted)
        m_curr=m_curr-learning_rate*dcm
        b_curr=b_curr-learning_rate*dcb 
        plt.plot(y_predicted)
        
        
        print(i   ,  m_curr    ,  b_curr    ,    cost_fun)
    
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

# %%
gredient_descent(x,y)
# Out:
# 0 0.062 0.018000000000000002 9.0
# 1 0.122528 0.035592000000000006 8.950696
# 2 0.181618832 0.052785648000000004 8.807422891456
# 3 0.239306503808 0.069590363712 8.576853067440995
# 4 0.29562421854195203 0.086015343961728 8.265292991033666
# 5 0.35060439367025875 0.10206956796255283 7.878701583081389
# 6 0.40427867960173774 0.11776180246460617 7.422707719899975
# 7 0.4566779778357119 0.13310060678206653 6.902626883247047
# 8 0.5078324586826338 0.14809433770148814 6.323477002909339
# 9 0.5577715785654069 0.16275115427398937 5.689993530341082
# 10 0.606524096911324 0.17707902249404894 5.006643779977209
# 11 0.6541180926443106 0.1910857198675929 4.277640573116625
# 12 0.7005809802869303 0.20477883987199186 3.5069552176236147
# 13 0.7459395256813859 0.2181657963105263 2.6983298551256816
# 14 0.7902198613385323 0.23125382756381693 1.8552892058900579
# 15 0.8334475014237017 0.2440500007406581 0.9811517401353975
# 16 0.8756473563879363 0.25656121573063456 0.07904030317643596
# ...
